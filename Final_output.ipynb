# %%
# %matplotlib inline

# %%
pip install ultralytics

# %%
import albumentations as A
import cv2
import numpy as np

import matplotlib.pyplot as plt

# %%
cd /content/drive/MyDrive/Projects/Cricket_bat_Corner_Detection
# Out:
# /content/drive/MyDrive/Projects/Cricket_bat_Corner_Detection

# %%
cd yolov5
# Out:
# /content/drive/MyDrive/Projects/Cricket_bat_Corner_Detection/yolov5

# %%
# Predicting the output with our obtained model made with 50 epochs

! python detect.py --source  '/content/drive/MyDrive/Projects/Cricket_bat_Corner_Detection/Kohli' --weights '/content/drive/MyDrive/Projects/Cricket_bat_Corner_Detection/yolov5/runs/train/exp/weights/best.pt'

# %%
# Predicting the output with our obtained model made with 330 epochs

! python detect.py --source  '/content/drive/MyDrive/Projects/Cricket_bat_Corner_Detection/Kohli' --weights '/content/drive/MyDrive/Projects/Cricket_bat_Corner_Detection/yolov5/runs/train/exp2/weights/best.pt'

# %%
image1 = cv2.imread("/content/drive/MyDrive/Projects/Cricket_bat_Corner_Detection/Output/Kohli_1.jpg")
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)

# %%
image2 = cv2.imread("/content/drive/MyDrive/Projects/Cricket_bat_Corner_Detection/Output/Kohli_2.jpg")
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Output From First Model with only 50 epochs

# %%
plt.figure(figsize=(12, 12))
plt.axis('off')
plt.imshow(image1)
plt.show()

# %% [markdown]
# ### Output From Second Model with 330 epochs

# %%
plt.figure(figsize=(12, 12))
plt.axis('off')
plt.imshow(image2)
plt.show()
